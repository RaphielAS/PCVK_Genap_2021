# %% [markdown]
# <a href="https://colab.research.google.com/github/RaphielAS/PCVK_Genap_2021/blob/main/Copy_of_Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#akses ke gdrive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
plt.imshow(img) #output gambar dari drive

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi warna gambar
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file gambar
#cv.imwrite('/content/drive/MyDrive/PCVK/mandrill2.tiff',img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))       #ubah ukuran sesuai keinginan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
img_gb = img.copy()
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
img_e = img[10:100,10:100]
plt.imshow(img_e)

# %%
plt.imshow(img3[5:30])

# %%
img666 = img3.copy()
cv.rectangle(img666, pt1=(25,0), pt2=(80,170), color=(255,255,0), thickness=10)
cv.rectangle(img666, pt1=(60,220), pt2=(510,150), color=(0,255,255),thickness=10)
cv.rectangle(img666, pt1=(250,367), pt2=(510,150), color=(255,0,255),thickness=10)
cv.rectangle(img666, pt1=(400,666), pt2=(510,150), color=(200,55,0),thickness=10)
cv.rectangle(img666, pt1=(3,700), pt2=(600,600), color=(100,100,80),thickness=10)
plt.imshow(img666)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
plt.imshow(img5)

# %%
imgrectacgle = img
cv.rectangle(imgrectacgle,pt1=(300,100), pt2=(500,300),color=(0,0,0),thickness=8)
cv.circle(imgrectacgle,center=(400,200),radius=100,color=(180,0,0),thickness=8)
plt.imshow(imgrectacgle)

# %%
cv.rectangle(img,pt1=(100,600),pt2=(0,500),color=(0,255,0),thickness=10)
plt.imshow(img)
